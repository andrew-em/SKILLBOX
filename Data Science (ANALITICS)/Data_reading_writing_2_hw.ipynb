# %% [markdown]
# # Чтение и запись данных, часть 2
#
# ## Практическая работа
#
# ### Описание практической работы и формат сдачи
#
# Выполните предложенные задачи: сохраните блокнот отдельно себе на диск и после этого пишите код в ячейках под задачами. Итоговый файл в формате `.ipynb` (файл Jupyter Notebook) загрузите в личный кабинет и отправьте на проверку.

# %% [markdown]
# ### Задача 1
#
# Используя сервис WeatherAPI, получите прогноз погоды в Лондоне на следующие 2 дня. Ответ преобразуйте к типу JSON.

# %%
API_KEY = "cf16a409c8124de995f110254221609"
days = 2
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=London&days={days}"

# %%
import urllib.request as req
import json

API_KEY = "96517f462e2141b4ae0114308233105"
days = 2
url = f"http://api.weatherapi.com/v1/forecast.json?key={API_KEY}&q=London&days={days}"

with req.urlopen(url) as session:
  response = session.read().decode()

data = json.loads(response)
data
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.52,
#   'lon': -0.11,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1699544442,
#   'localtime': '2023-11-09 15:40'},
#  'current': {'last_updated_epoch': 1699543800,
#   'last_updated': '2023-11-09 15:30',
#   'temp_c': 9.0,
#   'temp_f': 48.2,
#   'is_day': 1,
#   'condition': {'text': 'Moderate rain',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#    'code': 1189},
#   'wind_mph': 5.6,
#   'wind_kph': 9.0,
#   'wind_degree': 210,
#   'wind_dir': 'SSW',
#   'pressure_mb': 994.0,
#   'pressure_in': 29.35,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 81,
#   'cloud': 50,
#   'feelslike_c': 5.7,
#   'feelslike_f': 42.3,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 3.0,
#   'gust_mph': 20.6,
#   'gust_kph': 33.1},
#  'forecast': {'forecastday': [{'date': '2023-11-09',
#     'date_epoch': 1699488000,
#     'day': {'maxtemp_c': 10.4,
#      'maxtemp_f': 50.7,
#      'mintemp_c': 7.6,
#      'mintemp_f': 45.7,
#      'avgtemp_c': 8.7,
#      'avgtemp_f': 47.6,
#      'maxwind_mph': 15.4,
#      'maxwind_kph': 24.8,
#      'totalprecip_mm': 1.01,
#      'totalprecip_in': 0.04,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.5,
#      'avgvis_miles': 5.0,
#      'avghumidity': 74.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 89,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 2.0},
#     'astro': {'sunrise': '07:08 AM',
#      'sunset': '04:20 PM',
#      'moonrise': '02:25 AM',
#      'moonset': '03:03 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 18,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1699488000,
#       'time': '2023-11-09 00:00',
#       'temp_c': 7.8,
#       'temp_f': 46.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 1002.0,
#       'pressure_in': 29.58,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 50,
#       'feelslike_c': 6.4,
#       'feelslike_f': 43.6,
#       'windchill_c': 6.4,
#       'windchill_f': 43.6,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.0,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 1.0},
#      {'time_epoch': 1699491600,
#       'time': '2023-11-09 01:00',
#       'temp_c': 7.6,
#       'temp_f': 45.7,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 100,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.6,
#       'dewpoint_c': 4.9,
#       'dewpoint_f': 40.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 1.0},
#      {'time_epoch': 1699495200,
#       'time': '2023-11-09 02:00',
#       'temp_c': 7.7,
#       'temp_f': 45.9,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 215,
#       'wind_dir': 'SW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.56,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 7.7,
#       'heatindex_f': 45.9,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.2,
#       'uv': 1.0},
#      {'time_epoch': 1699498800,
#       'time': '2023-11-09 03:00',
#       'temp_c': 7.8,
#       'temp_f': 46.1,
#       'is_day': 0,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#        'code': 1009},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 216,
#       'wind_dir': 'SW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.55,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 96,
#       'feelslike_c': 5.9,
#       'feelslike_f': 42.6,
#       'windchill_c': 5.9,
#       'windchill_f': 42.6,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.1,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.9,
#       'gust_kph': 17.6,
#       'uv': 1.0},
#      {'time_epoch': 1699502400,
#       'time': '2023-11-09 04:00',
#       'temp_c': 7.8,
#       'temp_f': 46.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 201,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.54,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': 6.0,
#       'feelslike_f': 42.7,
#       'windchill_c': 6.0,
#       'windchill_f': 42.7,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.0,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 81,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.4,
#       'uv': 1.0},
#      {'time_epoch': 1699506000,
#       'time': '2023-11-09 05:00',
#       'temp_c': 8.0,
#       'temp_f': 46.4,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 196,
#       'wind_dir': 'SSW',
#       'pressure_mb': 999.0,
#       'pressure_in': 29.51,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 100,
#       'feelslike_c': 6.2,
#       'feelslike_f': 43.1,
#       'windchill_c': 6.2,
#       'windchill_f': 43.1,
#       'heatindex_c': 8.0,
#       'heatindex_f': 46.4,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 76,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.3,
#       'uv': 1.0},
#      {'time_epoch': 1699509600,
#       'time': '2023-11-09 06:00',
#       'temp_c': 8.7,
#       'temp_f': 47.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 201,
#       'wind_dir': 'SSW',
#       'pressure_mb': 999.0,
#       'pressure_in': 29.49,
#       'precip_mm': 0.04,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 83,
#       'feelslike_c': 6.5,
#       'feelslike_f': 43.6,
#       'windchill_c': 6.5,
#       'windchill_f': 43.6,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.6,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.4,
#       'will_it_rain': 1,
#       'chance_of_rain': 89,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.0,
#       'gust_kph': 22.5,
#       'uv': 1.0},
#      {'time_epoch': 1699513200,
#       'time': '2023-11-09 07:00',
#       'temp_c': 8.9,
#       'temp_f': 48.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 204,
#       'wind_dir': 'SSW',
#       'pressure_mb': 998.0,
#       'pressure_in': 29.47,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 62,
#       'feelslike_c': 6.9,
#       'feelslike_f': 44.3,
#       'windchill_c': 6.9,
#       'windchill_f': 44.3,
#       'heatindex_c': 8.9,
#       'heatindex_f': 48.1,
#       'dewpoint_c': 6.5,
#       'dewpoint_f': 43.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.2,
#       'gust_kph': 21.2,
#       'uv': 1.0},
#      {'time_epoch': 1699516800,
#       'time': '2023-11-09 08:00',
#       'temp_c': 8.8,
#       'temp_f': 47.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 998.0,
#       'pressure_in': 29.47,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 51,
#       'feelslike_c': 6.6,
#       'feelslike_f': 43.8,
#       'windchill_c': 6.6,
#       'windchill_f': 43.8,
#       'heatindex_c': 8.8,
#       'heatindex_f': 47.9,
#       'dewpoint_c': 6.4,
#       'dewpoint_f': 43.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.2,
#       'gust_kph': 22.9,
#       'uv': 3.0},
#      {'time_epoch': 1699520400,
#       'time': '2023-11-09 09:00',
#       'temp_c': 9.3,
#       'temp_f': 48.7,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 12.3,
#       'wind_kph': 19.8,
#       'wind_degree': 238,
#       'wind_dir': 'WSW',
#       'pressure_mb': 998.0,
#       'pressure_in': 29.47,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 45,
#       'feelslike_c': 6.5,
#       'feelslike_f': 43.6,
#       'windchill_c': 6.5,
#       'windchill_f': 43.6,
#       'heatindex_c': 9.3,
#       'heatindex_f': 48.7,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.6,
#       'gust_kph': 28.4,
#       'uv': 3.0},
#      {'time_epoch': 1699524000,
#       'time': '2023-11-09 10:00',
#       'temp_c': 9.4,
#       'temp_f': 48.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.1,
#       'wind_kph': 19.4,
#       'wind_degree': 225,
#       'wind_dir': 'SW',
#       'pressure_mb': 998.0,
#       'pressure_in': 29.46,
#       'precip_mm': 0.13,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 82,
#       'feelslike_c': 6.7,
#       'feelslike_f': 44.0,
#       'windchill_c': 6.7,
#       'windchill_f': 44.0,
#       'heatindex_c': 9.4,
#       'heatindex_f': 48.9,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 84,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.2,
#       'gust_kph': 26.1,
#       'uv': 2.0},
#      {'time_epoch': 1699527600,
#       'time': '2023-11-09 11:00',
#       'temp_c': 9.6,
#       'temp_f': 49.2,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 231,
#       'wind_dir': 'SW',
#       'pressure_mb': 997.0,
#       'pressure_in': 29.45,
#       'precip_mm': 0.11,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 84,
#       'feelslike_c': 6.8,
#       'feelslike_f': 44.2,
#       'windchill_c': 6.8,
#       'windchill_f': 44.2,
#       'heatindex_c': 9.6,
#       'heatindex_f': 49.2,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.6,
#       'gust_kph': 28.3,
#       'uv': 2.0},
#      {'time_epoch': 1699531200,
#       'time': '2023-11-09 12:00',
#       'temp_c': 10.3,
#       'temp_f': 50.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 13.6,
#       'wind_kph': 22.0,
#       'wind_degree': 242,
#       'wind_dir': 'WSW',
#       'pressure_mb': 996.0,
#       'pressure_in': 29.42,
#       'precip_mm': 0.01,
#       'precip_in': 0.0,
#       'humidity': 67,
#       'cloud': 84,
#       'feelslike_c': 7.6,
#       'feelslike_f': 45.6,
#       'windchill_c': 7.6,
#       'windchill_f': 45.6,
#       'heatindex_c': 10.3,
#       'heatindex_f': 50.5,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 83,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.3,
#       'gust_kph': 27.9,
#       'uv': 3.0},
#      {'time_epoch': 1699534800,
#       'time': '2023-11-09 13:00',
#       'temp_c': 10.4,
#       'temp_f': 50.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 246,
#       'wind_dir': 'WSW',
#       'pressure_mb': 996.0,
#       'pressure_in': 29.41,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 89,
#       'feelslike_c': 7.5,
#       'feelslike_f': 45.5,
#       'windchill_c': 7.5,
#       'windchill_f': 45.5,
#       'heatindex_c': 10.4,
#       'heatindex_f': 50.7,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.9,
#       'gust_kph': 30.5,
#       'uv': 3.0},
#      {'time_epoch': 1699538400,
#       'time': '2023-11-09 14:00',
#       'temp_c': 10.2,
#       'temp_f': 50.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 14.8,
#       'wind_kph': 23.8,
#       'wind_degree': 242,
#       'wind_dir': 'WSW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.39,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 10,
#       'feelslike_c': 7.3,
#       'feelslike_f': 45.1,
#       'windchill_c': 7.3,
#       'windchill_f': 45.1,
#       'heatindex_c': 10.2,
#       'heatindex_f': 50.3,
#       'dewpoint_c': 3.5,
#       'dewpoint_f': 38.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 19.2,
#       'gust_kph': 30.9,
#       'uv': 4.0},
#      {'time_epoch': 1699542000,
#       'time': '2023-11-09 15:00',
#       'temp_c': 9.0,
#       'temp_f': 48.2,
#       'is_day': 1,
#       'condition': {'text': 'Moderate rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/302.png',
#        'code': 1189},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 210,
#       'wind_dir': 'SSW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 50,
#       'feelslike_c': 6.7,
#       'feelslike_f': 44.0,
#       'windchill_c': 6.7,
#       'windchill_f': 44.0,
#       'heatindex_c': 9.7,
#       'heatindex_f': 49.5,
#       'dewpoint_c': 2.8,
#       'dewpoint_f': 37.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.6,
#       'gust_kph': 33.1,
#       'uv': 3.0},
#      {'time_epoch': 1699545600,
#       'time': '2023-11-09 16:00',
#       'temp_c': 9.0,
#       'temp_f': 48.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 13.0,
#       'wind_kph': 20.9,
#       'wind_degree': 221,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.36,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 63,
#       'cloud': 22,
#       'feelslike_c': 6.0,
#       'feelslike_f': 42.8,
#       'windchill_c': 6.0,
#       'windchill_f': 42.8,
#       'heatindex_c': 9.0,
#       'heatindex_f': 48.2,
#       'dewpoint_c': 2.3,
#       'dewpoint_f': 36.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 18.9,
#       'gust_kph': 30.4,
#       'uv': 3.0},
#      {'time_epoch': 1699549200,
#       'time': '2023-11-09 17:00',
#       'temp_c': 8.7,
#       'temp_f': 47.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/263.png',
#        'code': 1150},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 228,
#       'wind_dir': 'SW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.37,
#       'precip_mm': 0.18,
#       'precip_in': 0.01,
#       'humidity': 66,
#       'cloud': 74,
#       'feelslike_c': 5.3,
#       'feelslike_f': 41.6,
#       'windchill_c': 5.3,
#       'windchill_f': 41.6,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.6,
#       'dewpoint_c': 2.7,
#       'dewpoint_f': 36.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 22.0,
#       'gust_kph': 35.4,
#       'uv': 1.0},
#      {'time_epoch': 1699552800,
#       'time': '2023-11-09 18:00',
#       'temp_c': 8.7,
#       'temp_f': 47.7,
#       'is_day': 0,
#       'condition': {'text': 'Light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/266.png',
#        'code': 1153},
#       'wind_mph': 15.4,
#       'wind_kph': 24.8,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.36,
#       'precip_mm': 0.22,
#       'precip_in': 0.01,
#       'humidity': 69,
#       'cloud': 100,
#       'feelslike_c': 5.3,
#       'feelslike_f': 41.6,
#       'windchill_c': 5.3,
#       'windchill_f': 41.6,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.7,
#       'dewpoint_c': 3.4,
#       'dewpoint_f': 38.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 2.0,
#       'vis_miles': 1.0,
#       'gust_mph': 21.9,
#       'gust_kph': 35.3,
#       'uv': 1.0},
#      {'time_epoch': 1699556400,
#       'time': '2023-11-09 19:00',
#       'temp_c': 8.1,
#       'temp_f': 46.6,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 14.5,
#       'wind_kph': 23.4,
#       'wind_degree': 237,
#       'wind_dir': 'WSW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.37,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 72,
#       'feelslike_c': 4.7,
#       'feelslike_f': 40.4,
#       'windchill_c': 4.7,
#       'windchill_f': 40.4,
#       'heatindex_c': 8.1,
#       'heatindex_f': 46.6,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.0,
#       'gust_kph': 32.2,
#       'uv': 1.0},
#      {'time_epoch': 1699560000,
#       'time': '2023-11-09 20:00',
#       'temp_c': 8.0,
#       'temp_f': 46.5,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 14.1,
#       'wind_kph': 22.7,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.37,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 70,
#       'feelslike_c': 4.6,
#       'feelslike_f': 40.3,
#       'windchill_c': 4.6,
#       'windchill_f': 40.3,
#       'heatindex_c': 8.0,
#       'heatindex_f': 46.5,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 65,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.9,
#       'gust_kph': 33.6,
#       'uv': 1.0},
#      {'time_epoch': 1699563600,
#       'time': '2023-11-09 21:00',
#       'temp_c': 8.0,
#       'temp_f': 46.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 13.9,
#       'wind_kph': 22.3,
#       'wind_degree': 234,
#       'wind_dir': 'SW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.37,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 74,
#       'cloud': 25,
#       'feelslike_c': 4.7,
#       'feelslike_f': 40.4,
#       'windchill_c': 4.7,
#       'windchill_f': 40.4,
#       'heatindex_c': 8.0,
#       'heatindex_f': 46.5,
#       'dewpoint_c': 3.7,
#       'dewpoint_f': 38.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.1,
#       'gust_kph': 34.0,
#       'uv': 1.0},
#      {'time_epoch': 1699567200,
#       'time': '2023-11-09 22:00',
#       'temp_c': 7.8,
#       'temp_f': 46.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 13.9,
#       'wind_kph': 22.3,
#       'wind_degree': 230,
#       'wind_dir': 'SW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.37,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 36,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.7,
#       'windchill_c': 4.3,
#       'windchill_f': 39.7,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.0,
#       'dewpoint_c': 2.9,
#       'dewpoint_f': 37.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 21.2,
#       'gust_kph': 34.1,
#       'uv': 1.0},
#      {'time_epoch': 1699570800,
#       'time': '2023-11-09 23:00',
#       'temp_c': 7.8,
#       'temp_f': 46.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 13.4,
#       'wind_kph': 21.6,
#       'wind_degree': 229,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.08,
#       'precip_in': 0.0,
#       'humidity': 71,
#       'cloud': 100,
#       'feelslike_c': 4.4,
#       'feelslike_f': 40.0,
#       'windchill_c': 4.4,
#       'windchill_f': 40.0,
#       'heatindex_c': 7.8,
#       'heatindex_f': 46.0,
#       'dewpoint_c': 2.9,
#       'dewpoint_f': 37.1,
#       'will_it_rain': 1,
#       'chance_of_rain': 71,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 20.4,
#       'gust_kph': 32.9,
#       'uv': 1.0}]},
#    {'date': '2023-11-10',
#     'date_epoch': 1699574400,
#     'day': {'maxtemp_c': 9.0,
#      'maxtemp_f': 48.2,
#      'mintemp_c': 6.3,
#      'mintemp_f': 43.3,
#      'avgtemp_c': 7.5,
#      'avgtemp_f': 45.6,
#      'maxwind_mph': 11.2,
#      'maxwind_kph': 18.0,
#      'totalprecip_mm': 3.33,
#      'totalprecip_in': 0.13,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.8,
#      'avgvis_miles': 6.0,
#      'avghumidity': 84.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 89,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 2.0},
#     'astro': {'sunrise': '07:09 AM',
#      'sunset': '04:18 PM',
#      'moonrise': '03:37 AM',
#      'moonset': '03:13 PM',
#      'moon_phase': 'Waning Crescent',
#      'moon_illumination': 11,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1699574400,
#       'time': '2023-11-10 00:00',
#       'temp_c': 6.3,
#       'temp_f': 43.4,
#       'is_day': 0,
#       'condition': {'text': 'Light rain',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/296.png',
#        'code': 1183},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 218,
#       'wind_dir': 'SW',
#       'pressure_mb': 993.0,
#       'pressure_in': 29.33,
#       'precip_mm': 2.11,
#       'precip_in': 0.08,
#       'humidity': 88,
#       'cloud': 100,
#       'feelslike_c': 3.6,
#       'feelslike_f': 38.4,
#       'windchill_c': 3.6,
#       'windchill_f': 38.4,
#       'heatindex_c': 6.3,
#       'heatindex_f': 43.4,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 40.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.2,
#       'uv': 1.0},
#      {'time_epoch': 1699578000,
#       'time': '2023-11-10 01:00',
#       'temp_c': 7.4,
#       'temp_f': 45.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 242,
#       'wind_dir': 'WSW',
#       'pressure_mb': 992.0,
#       'pressure_in': 29.3,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 90,
#       'feelslike_c': 4.9,
#       'feelslike_f': 40.7,
#       'windchill_c': 4.9,
#       'windchill_f': 40.7,
#       'heatindex_c': 7.4,
#       'heatindex_f': 45.2,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 66,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.3,
#       'uv': 1.0},
#      {'time_epoch': 1699581600,
#       'time': '2023-11-10 02:00',
#       'temp_c': 7.5,
#       'temp_f': 45.6,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 993.0,
#       'pressure_in': 29.31,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 79,
#       'feelslike_c': 4.9,
#       'feelslike_f': 40.9,
#       'windchill_c': 4.9,
#       'windchill_f': 40.9,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.6,
#       'dewpoint_c': 5.5,
#       'dewpoint_f': 41.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.7,
#       'uv': 1.0},
#      {'time_epoch': 1699585200,
#       'time': '2023-11-10 03:00',
#       'temp_c': 7.4,
#       'temp_f': 45.2,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 993.0,
#       'pressure_in': 29.31,
#       'precip_mm': 0.02,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 85,
#       'feelslike_c': 5.0,
#       'feelslike_f': 40.9,
#       'windchill_c': 5.0,
#       'windchill_f': 40.9,
#       'heatindex_c': 7.4,
#       'heatindex_f': 45.2,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 1,
#       'chance_of_rain': 87,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.3,
#       'uv': 1.0},
#      {'time_epoch': 1699588800,
#       'time': '2023-11-10 04:00',
#       'temp_c': 7.1,
#       'temp_f': 44.8,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 258,
#       'wind_dir': 'WSW',
#       'pressure_mb': 993.0,
#       'pressure_in': 29.33,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 71,
#       'feelslike_c': 4.4,
#       'feelslike_f': 39.9,
#       'windchill_c': 4.4,
#       'windchill_f': 39.9,
#       'heatindex_c': 7.1,
#       'heatindex_f': 44.8,
#       'dewpoint_c': 5.4,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.1,
#       'gust_kph': 22.6,
#       'uv': 1.0},
#      {'time_epoch': 1699592400,
#       'time': '2023-11-10 05:00',
#       'temp_c': 6.8,
#       'temp_f': 44.3,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 246,
#       'wind_dir': 'WSW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.34,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 37,
#       'feelslike_c': 4.2,
#       'feelslike_f': 39.6,
#       'windchill_c': 4.2,
#       'windchill_f': 39.6,
#       'heatindex_c': 6.8,
#       'heatindex_f': 44.3,
#       'dewpoint_c': 4.9,
#       'dewpoint_f': 40.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 13.3,
#       'gust_kph': 21.4,
#       'uv': 1.0},
#      {'time_epoch': 1699596000,
#       'time': '2023-11-10 06:00',
#       'temp_c': 6.7,
#       'temp_f': 44.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 236,
#       'wind_dir': 'WSW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.34,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'humidity': 86,
#       'cloud': 67,
#       'feelslike_c': 4.2,
#       'feelslike_f': 39.5,
#       'windchill_c': 4.2,
#       'windchill_f': 39.5,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.1,
#       'dewpoint_c': 4.6,
#       'dewpoint_f': 40.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 89,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.8,
#       'gust_kph': 20.6,
#       'uv': 1.0},
#      {'time_epoch': 1699599600,
#       'time': '2023-11-10 07:00',
#       'temp_c': 6.7,
#       'temp_f': 44.1,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 223,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.21,
#       'precip_in': 0.01,
#       'humidity': 91,
#       'cloud': 90,
#       'feelslike_c': 4.3,
#       'feelslike_f': 39.8,
#       'windchill_c': 4.3,
#       'windchill_f': 39.8,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.1,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 65,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.0,
#       'gust_kph': 19.3,
#       'uv': 1.0},
#      {'time_epoch': 1699603200,
#       'time': '2023-11-10 08:00',
#       'temp_c': 7.3,
#       'temp_f': 45.2,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 217,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.16,
#       'precip_in': 0.01,
#       'humidity': 90,
#       'cloud': 80,
#       'feelslike_c': 5.3,
#       'feelslike_f': 41.5,
#       'windchill_c': 5.3,
#       'windchill_f': 41.5,
#       'heatindex_c': 7.3,
#       'heatindex_f': 45.2,
#       'dewpoint_c': 5.8,
#       'dewpoint_f': 42.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.1,
#       'gust_kph': 16.3,
#       'uv': 2.0},
#      {'time_epoch': 1699606800,
#       'time': '2023-11-10 09:00',
#       'temp_c': 8.0,
#       'temp_f': 46.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 203,
#       'wind_dir': 'SSW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.05,
#       'precip_in': 0.0,
#       'humidity': 87,
#       'cloud': 69,
#       'feelslike_c': 6.9,
#       'feelslike_f': 44.3,
#       'windchill_c': 6.9,
#       'windchill_f': 44.3,
#       'heatindex_c': 8.0,
#       'heatindex_f': 46.4,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 62,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.3,
#       'gust_kph': 10.1,
#       'uv': 2.0},
#      {'time_epoch': 1699610400,
#       'time': '2023-11-10 10:00',
#       'temp_c': 8.8,
#       'temp_f': 47.8,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 220,
#       'wind_dir': 'SW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.35,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 94,
#       'feelslike_c': 7.6,
#       'feelslike_f': 45.7,
#       'windchill_c': 7.6,
#       'windchill_f': 45.7,
#       'heatindex_c': 8.8,
#       'heatindex_f': 47.8,
#       'dewpoint_c': 6.0,
#       'dewpoint_f': 42.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 72,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.5,
#       'gust_kph': 10.5,
#       'uv': 2.0},
#      {'time_epoch': 1699614000,
#       'time': '2023-11-10 11:00',
#       'temp_c': 8.9,
#       'temp_f': 48.1,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 290,
#       'wind_dir': 'WNW',
#       'pressure_mb': 994.0,
#       'pressure_in': 29.36,
#       'precip_mm': 0.07,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 100,
#       'feelslike_c': 8.7,
#       'feelslike_f': 47.6,
#       'windchill_c': 8.7,
#       'windchill_f': 47.6,
#       'heatindex_c': 8.9,
#       'heatindex_f': 48.1,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.9,
#       'gust_kph': 6.3,
#       'uv': 2.0},
#      {'time_epoch': 1699617600,
#       'time': '2023-11-10 12:00',
#       'temp_c': 8.7,
#       'temp_f': 47.7,
#       'is_day': 1,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/353.png',
#        'code': 1240},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 329,
#       'wind_dir': 'NNW',
#       'pressure_mb': 995.0,
#       'pressure_in': 29.38,
#       'precip_mm': 0.32,
#       'precip_in': 0.01,
#       'humidity': 85,
#       'cloud': 100,
#       'feelslike_c': 6.7,
#       'feelslike_f': 44.1,
#       'windchill_c': 6.7,
#       'windchill_f': 44.1,
#       'heatindex_c': 8.7,
#       'heatindex_f': 47.7,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.3,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.0,
#       'gust_kph': 16.1,
#       'uv': 2.0},
#      {'time_epoch': 1699621200,
#       'time': '2023-11-10 13:00',
#       'temp_c': 8.2,
#       'temp_f': 46.7,
#       'is_day': 1,
#       'condition': {'text': 'Patchy light drizzle',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/263.png',
#        'code': 1150},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 332,
#       'wind_dir': 'NNW',
#       'pressure_mb': 996.0,
#       'pressure_in': 29.42,
#       'precip_mm': 0.2,
#       'precip_in': 0.01,
#       'humidity': 86,
#       'cloud': 63,
#       'feelslike_c': 5.8,
#       'feelslike_f': 42.4,
#       'windchill_c': 5.8,
#       'windchill_f': 42.4,
#       'heatindex_c': 8.2,
#       'heatindex_f': 46.7,
#       'dewpoint_c': 6.0,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 51,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 5.0,
#       'vis_miles': 3.0,
#       'gust_mph': 12.3,
#       'gust_kph': 19.7,
#       'uv': 2.0},
#      {'time_epoch': 1699624800,
#       'time': '2023-11-10 14:00',
#       'temp_c': 8.9,
#       'temp_f': 48.1,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 320,
#       'wind_dir': 'NW',
#       'pressure_mb': 998.0,
#       'pressure_in': 29.46,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 79,
#       'cloud': 37,
#       'feelslike_c': 6.4,
#       'feelslike_f': 43.5,
#       'windchill_c': 6.4,
#       'windchill_f': 43.5,
#       'heatindex_c': 9.0,
#       'heatindex_f': 48.1,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.4,
#       'gust_kph': 23.1,
#       'uv': 3.0},
#      {'time_epoch': 1699628400,
#       'time': '2023-11-10 15:00',
#       'temp_c': 9.0,
#       'temp_f': 48.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 11.2,
#       'wind_kph': 18.0,
#       'wind_degree': 314,
#       'wind_dir': 'NW',
#       'pressure_mb': 999.0,
#       'pressure_in': 29.5,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 75,
#       'cloud': 20,
#       'feelslike_c': 6.3,
#       'feelslike_f': 43.3,
#       'windchill_c': 6.3,
#       'windchill_f': 43.3,
#       'heatindex_c': 9.0,
#       'heatindex_f': 48.2,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.9,
#       'gust_kph': 25.5,
#       'uv': 3.0},
#      {'time_epoch': 1699632000,
#       'time': '2023-11-10 16:00',
#       'temp_c': 8.2,
#       'temp_f': 46.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 302,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.53,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 18,
#       'feelslike_c': 5.5,
#       'feelslike_f': 41.9,
#       'windchill_c': 5.5,
#       'windchill_f': 41.9,
#       'heatindex_c': 8.2,
#       'heatindex_f': 46.8,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.3,
#       'gust_kph': 26.2,
#       'uv': 3.0},
#      {'time_epoch': 1699635600,
#       'time': '2023-11-10 17:00',
#       'temp_c': 7.6,
#       'temp_f': 45.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 294,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 77,
#       'cloud': 8,
#       'feelslike_c': 4.9,
#       'feelslike_f': 40.9,
#       'windchill_c': 4.9,
#       'windchill_f': 40.9,
#       'heatindex_c': 7.6,
#       'heatindex_f': 45.7,
#       'dewpoint_c': 3.9,
#       'dewpoint_f': 39.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.3,
#       'gust_kph': 24.6,
#       'uv': 1.0},
#      {'time_epoch': 1699639200,
#       'time': '2023-11-10 18:00',
#       'temp_c': 7.5,
#       'temp_f': 45.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 9.8,
#       'wind_kph': 15.8,
#       'wind_degree': 287,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1002.0,
#       'pressure_in': 29.58,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 80,
#       'cloud': 19,
#       'feelslike_c': 4.7,
#       'feelslike_f': 40.4,
#       'windchill_c': 4.7,
#       'windchill_f': 40.4,
#       'heatindex_c': 7.5,
#       'heatindex_f': 45.4,
#       'dewpoint_c': 4.3,
#       'dewpoint_f': 39.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.8,
#       'gust_kph': 25.4,
#       'uv': 1.0},
#      {'time_epoch': 1699642800,
#       'time': '2023-11-10 19:00',
#       'temp_c': 7.3,
#       'temp_f': 45.1,
#       'is_day': 0,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#        'code': 1006},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.61,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 82,
#       'cloud': 82,
#       'feelslike_c': 4.2,
#       'feelslike_f': 39.6,
#       'windchill_c': 4.2,
#       'windchill_f': 39.6,
#       'heatindex_c': 7.3,
#       'heatindex_f': 45.1,
#       'dewpoint_c': 4.5,
#       'dewpoint_f': 40.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.3,
#       'gust_kph': 27.8,
#       'uv': 1.0},
#      {'time_epoch': 1699646400,
#       'time': '2023-11-10 20:00',
#       'temp_c': 7.0,
#       'temp_f': 44.6,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.5,
#       'wind_kph': 16.9,
#       'wind_degree': 278,
#       'wind_dir': 'W',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.63,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 83,
#       'cloud': 59,
#       'feelslike_c': 4.0,
#       'feelslike_f': 39.1,
#       'windchill_c': 4.0,
#       'windchill_f': 39.1,
#       'heatindex_c': 7.0,
#       'heatindex_f': 44.6,
#       'dewpoint_c': 4.4,
#       'dewpoint_f': 39.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.6,
#       'uv': 1.0},
#      {'time_epoch': 1699650000,
#       'time': '2023-11-10 21:00',
#       'temp_c': 6.7,
#       'temp_f': 44.1,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 10.7,
#       'wind_kph': 17.3,
#       'wind_degree': 275,
#       'wind_dir': 'W',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.64,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 84,
#       'cloud': 27,
#       'feelslike_c': 3.6,
#       'feelslike_f': 38.4,
#       'windchill_c': 3.6,
#       'windchill_f': 38.4,
#       'heatindex_c': 6.7,
#       'heatindex_f': 44.1,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.8,
#       'gust_kph': 27.1,
#       'uv': 1.0},
#      {'time_epoch': 1699653600,
#       'time': '2023-11-10 22:00',
#       'temp_c': 6.5,
#       'temp_f': 43.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 269,
#       'wind_dir': 'W',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 15,
#       'feelslike_c': 3.4,
#       'feelslike_f': 38.1,
#       'windchill_c': 3.4,
#       'windchill_f': 38.1,
#       'heatindex_c': 6.5,
#       'heatindex_f': 43.8,
#       'dewpoint_c': 4.2,
#       'dewpoint_f': 39.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.0,
#       'gust_kph': 25.8,
#       'uv': 1.0},
#      {'time_epoch': 1699657200,
#       'time': '2023-11-10 23:00',
#       'temp_c': 6.3,
#       'temp_f': 43.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 267,
#       'wind_dir': 'W',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 85,
#       'cloud': 10,
#       'feelslike_c': 3.2,
#       'feelslike_f': 37.7,
#       'windchill_c': 3.2,
#       'windchill_f': 37.7,
#       'heatindex_c': 6.3,
#       'heatindex_f': 43.3,
#       'dewpoint_c': 4.0,
#       'dewpoint_f': 39.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.7,
#       'gust_kph': 25.3,
#       'uv': 1.0}]}]}}

# %% [markdown]
# ### Задача 2
#
# Сохраните данные погоды, полученные в предыдущей задаче, в файл `weather.json`. При сохранении используйте четыре пробела для форматирования.

# %%
with open('weather.json', 'w') as file:
    json.dump(data, file, indent=4)

# %% [markdown]
# ### Задача 3
#
# Из содержимого файла `weather.json` получите **почасовой** прогноз погоды, загрузите его в DataFrame и выведите первые пять строк DataFrame на экран.

# %%
import pandas as pd

with open('weather.json', 'r') as file:
    s = json.load(file)
       
d = []

for i in range(days):
  d_outer = s['forecast']['forecastday'][i]
  d = d + d_outer['hour']
df = pd.DataFrame(d)
df.head()
# Out:
#    time_epoch              time  temp_c  temp_f  is_day  \
# 0  1697670000  2023-10-19 00:00    15.3    59.6       0
# 1  1697673600  2023-10-19 01:00    14.6    58.3       0
# 2  1697677200  2023-10-19 02:00    14.4    58.0       0
# 3  1697680800  2023-10-19 03:00    15.7    60.2       0
# 4  1697684400  2023-10-19 04:00    15.9    60.5       0
#
#                                            condition  wind_mph  wind_kph  \
# 0  {'text': 'Overcast', 'icon': '//cdn.weatherapi...      17.2      27.7
# 1  {'text': 'Partly cloudy', 'icon': '//cdn.weath...      15.4      24.8
# 2  {'text': 'Overcast', 'icon': '//cdn.weatherapi...      12.3      19.8
# 3  {'text': 'Patchy rain possible', 'icon': '//cd...      13.0      20.9
# 4  {'text': 'Patchy rain possible', 'icon': '//cd...      12.8      20.5
#
#    wind_degree wind_dir  ...  dewpoint_f  will_it_rain  chance_of_rain  \
# 0          218       SW  ...        54.6             0               0
# 1          218       SW  ...        53.1             0               0
# 2          214       SW  ...        55.2             0               0
# 3          198      SSW  ...        57.7             1              83
# 4          191      SSW  ...        57.3             1              84
#
#    will_it_snow  chance_of_snow  vis_km  vis_miles  gust_mph  gust_kph   uv
# 0             0               0    10.0        6.0      24.6      39.5  1.0
# 1             0               0    10.0        6.0      22.7      36.6  1.0
# 2             0               0    10.0        6.0      19.0      30.5  1.0
# 3             0               0    10.0        6.0      19.5      31.4  1.0
# 4             0               0    10.0        6.0      19.1      30.8  1.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Задача 4
#
# Сохраните DataFrame из предыдущей задачи в файл `result.csv`. В качестве названия столбца-индекса используйте `index`.

# %%
df.to_csv('result.csv', index=True)

# %% [markdown]
# ### Задача 5
#
# Загрузите содержимое SQL-таблицы `ratings` в DataFrame. Выведите первые пять строк DataFrame на экран. Для подключения к БД используйте строку подключения, указанную в следующей ячейке.

# %%
connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'

# %%
import sqlalchemy
import psycopg2

connection = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'

engine = sqlalchemy.create_engine(connection)
connect = engine.connect()
# Out:
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\pool\base.py", line 697, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\pool\base.py", line 893, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\engine\default.py", line 543, in do_rollback
#     dbapi_connection.rollback()
# psycopg2.OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords']

# %%
df = pd.read_sql("select * from ratings", connect)
df.head(5)
# Out:
#    userid  movieid  rating   timestamp
# 0    5991     4992     3.5  1226450424
# 1    5991     4993     2.5  1226595228
# 2    5991     5047     4.0  1226600333
# 3    5991     5079     4.0  1226450298
# 4    5991     5296     3.0  1226532779

# %% [markdown]
# ### Задача 6
#
# Сохраните первые 10000 записей датафрейма из предыдущей задачи в файл `result2.xlsx`, при сохранении задайте листу имя `MySheet`.
#
# (Примечание: для указания имени листа в файле Excel как при чтении, так и при записи используется параметр `sheet_name`)

# %%
df_10000 = df.head(10000)

# %%
df_10000.to_excel('result2.xlsx', sheet_name='MySheet', index=True)

# %% [markdown]
# ### Задача 7
#
# Определите количество документов в коллекции `users` в MongoDB. Если количество документов < 1000, то в следующей ячейке загрузите всё содержимое этой коллекции в список и выведите нулевой элемент этого списка на экран. Для подключения к MongoDB используйте строку подключения, указанную в следующей ячейке.

# %%
conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'

# %%
import pymongo

conn = 'mongodb://students:X63673t47Gl03Sq@dsstudents.skillbox.ru:27017/?authSource=movies'

client = pymongo.MongoClient(conn)

db = client['movies']

# %%
db.list_collection_names()
# Out:
# ['tags', 'users']

# %%
users = db['users']
users.find_one()
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %%
users.count_documents({})
# Out:
# 100

# %%
head = users.find()
my_list = list(head)

my_list[0]
# Out:
# {'_id': ObjectId('5cc69095067496679c74f7a4'),
#  'user_id': 'ed5da480-57a2-489c-8e68-512155ab9892',
#  'first_name': 'Жанна',
#  'last_name': 'Петрова',
#  'mail': 'zhanna_03816@gmail.com',
#  'age': 20.0}

# %% [markdown]
# ### Задача 8
#
# Преобразуйте список всех документов коллекции `users` из предыдущей задачи в pandas DataFrame и сохраните его содержимое в файл `result3.xlsx`.

# %%
df_users = pd.DataFrame(my_list)

# %%
df_users.to_excel('result3.xlsx', sheet_name='MySheet', index=True)

# %% [markdown]
# ## Дополнительные (необязательные) задачи
#
# ### Задача 9
#
# Используя данные SQL-таблицы `ratings`, для каждого пользователя (столбец `userid`) определите средний рейтинг, который этот пользователь поставил фильмам. Результат выведите на экран.
#
# Группировку проведите двумя способами: с помощью `GROUP BY` в строке запроса к БД и с использованием метода `groupby` в pandas.
#
# Для подключения к БД используйте строку подключения в следующей ячейке

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()
# Out:
# Exception during reset or similar
# Traceback (most recent call last):
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\pool\base.py", line 697, in _finalize_fairy
#     fairy._reset(pool)
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\pool\base.py", line 893, in _reset
#     pool._dialect.do_rollback(self)
#   File "C:\IT\SOFT\lib\site-packages\sqlalchemy\engine\default.py", line 543, in do_rollback
#     dbapi_connection.rollback()
# psycopg2.OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords']

# %%
df = pd.read_sql("select * from ratings", connect)
df.head(5)
# Out:
#    userid  movieid  rating   timestamp
# 0    5991     4992     3.5  1226450424
# 1    5991     4993     2.5  1226595228
# 2    5991     5047     4.0  1226600333
# 3    5991     5079     4.0  1226450298
# 4    5991     5296     3.0  1226532779

# %%
df['avg'] = df.groupby('userid')['rating'].mean()
df.groupby('userid')['avg'].count()
df.head()
# Out:
#    userid  movieid  rating   timestamp       avg
# 0    5991     4992     3.5  1226450424       NaN
# 1    5991     4993     2.5  1226595228  4.277778
# 2    5991     5047     4.0  1226600333  3.318182
# 3    5991     5079     4.0  1226450298  3.100000
# 4    5991     5296     3.0  1226532779  3.500000

# %%
df = pd.read_sql("select userid, avg(rating) from ratings group by userid", connect)
df.head()
# Out:
#    userid       avg
# 0    6114  4.000000
# 1    4790  4.000000
# 2     273  4.314685
# 3    3936  3.756757
# 4    5761  3.419220

# %% [markdown]
# ### Задача 10
#
# Объедините таблицы `ratings` и `keywords` по столбцам `movieid` (используйте левое объединение). Объединение проведите двумя способами: с помощью `LEFT JOIN` в строке запроса к БД и с использованием метода `merge` в pandas. Результат объединения загрузите в DataFrame и сохраните в файл `result4.csv`.
#
# Обратите внимание, что при объединении возможно дублирование столбцов. В результирующем датафрейме не должно быть таких дублированных столбцов.

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'

# %%
conn = 'postgresql+psycopg2://readonly:6hajV34RTQfmxhS@dsstudents.skillbox.ru:5433/db_ds_students'

engine = sqlalchemy.create_engine(conn)
connect = engine.connect()

# %%
inspector = sqlalchemy.inspect(engine)
inspector.get_table_names()
# Out:
# ['links',
#  'joi',
#  'mobile',
#  'new_table',
#  'course_purchases',
#  'orders',
#  'sales',
#  'exploratory',
#  'studentt',
#  'superheroes',
#  'users',
#  'product_types',
#  'products',
#  'ratings',
#  'keywords']

# %%
df_united = pd.read_sql('SELECT userid, ratings.movieid, rating, timestamp, tags\
                        FROM ratings LEFT JOIN keywords ON ratings.movieid = keywords.movieid', connect)
df_united.head()
# Out:
#    userid  movieid  rating   timestamp  \
# 0    5991     4992     3.5  1226450424
# 1    5991     4992     3.5  1226450424
# 2    5991     4993     2.5  1226595228
# 3    5991     4993     2.5  1226595228
# 4    5991     5952     2.0  1226595231
#
#                                                 tags
# 0  [{'id': 658, 'name': 'sea'}, {'id': 1522, 'nam...
# 1  [{'id': 658, 'name': 'sea'}, {'id': 1522, 'nam...
# 2  [{'id': 383, 'name': 'poker'}, {'id': 9826, 'n...
# 3  [{'id': 383, 'name': 'poker'}, {'id': 9826, 'n...
# 4                                               None

# %%
df_ratings = pd.read_sql('SELECT DISTINCT * FROM ratings', connect)

df_keywords = pd.read_sql('SELECT DISTINCT * FROM keywords', connect)

df_merged = df_ratings.merge(df_keywords, on='movieid', how='left')

# %%
df_diff = df_keywords.columns.difference(df_ratings.columns)
df_merged.head()
# Out:
#    userid  movieid  rating   timestamp  \
# 0    6049     3036     2.0   945118400
# 1    6188      316     4.0  1079998588
# 2    6118      736     3.5  1203994020
# 3    6059     1226     3.0   940066049
# 4    6031     4022     5.0  1488476774
#
#                                                 tags
# 0  [{'id': 4005, 'name': 'human experimentation'}...
# 1  [{'id': 596, 'name': 'adultery'}, {'id': 1157,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df_un = pd.DataFrame(df_merged)

# %%
df_un.to_excel('result4.xlsx', sheet_name='MySheet', index=True)

# %% [markdown]
# ### Задача 11
#
# Используя объединенную таблицу из предыдущего задания, найдите все идентификаторы фильмов с тегом `africa` (но не `south africa` или любые другие). Список тегов в формате JSON записан в столбце `tags`.

# %%
df_tags = df_un.drop(['userid', 'movieid', 'rating', 'timestamp'], axis=1)
df_tags.head()
# Out:
#                                                 tags
# 0  [{'id': 4005, 'name': 'human experimentation'}...
# 1  [{'id': 596, 'name': 'adultery'}, {'id': 1157,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
africa_movieid_list = df_un['movieid'][
    df_un['tags'].apply(lambda tags: tags.find("'africa'") >= 0)
].unique().tolist()
